# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf

import matplotlib.pyplot as plt
import math
from datetime import datetime
from tqdm import tqdm
import seaborn as sns



wd = "D:/temp/2025-JPM-MLCOE-internship/programs"
os.chdir(wd)

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 10
#       8 from datetime import datetime
#       9 from tqdm import tqdm
# ---> 10 import seaborn as sns
#      14 wd = "D:/temp/2025-JPM-MLCOE-internship/programs"
#      15 os.chdir(wd)
#
# File c:\Users\FBE RPG\anaconda3\lib\site-packages\seaborn\__init__.py:5
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
# ----> 5 from .relational import *  # noqa: F401,F403
#       6 from .regression import *  # noqa: F401,F403
#       7 from .categorical import *  # noqa: F401,F403
#
# File c:\Users\FBE RPG\anaconda3\lib\site-packages\seaborn\relational.py:17
#       8 from ._oldcore import (
#       9     VectorPlotter,
#      10 )
#      11 from .utils import (
#      12     locator_to_legend_entries,
#      13     adjust_legend_subtitles,
# ...

# %%
df = pd.read_csv("Nasdaq100_1990-2023annual_balancesheet.csv")

# %%
df.describe().transpose()
# Out:
# c:\Users\FBE RPG\anaconda3\lib\site-packages\IPython\core\formatters.py:344: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
#         count          mean           std        min       25%         50%
# gvkey  2584.0  44446.440015  55212.134659   1161.000  7343.000  24344.0000  \
# fyear  2584.0   2008.394737      9.476857   1989.000  2001.000   2009.0000
# at     2572.0  22178.162084  46874.637374      0.288  1373.391   5612.5295
# lt     2561.0  12756.585016  29023.597676      0.107   467.192   2636.0000
# teq    1965.0  11408.325423  24030.633026 -10506.000   833.943   3181.4620
#
#                75%       max
# gvkey  39337.00000  184996.0
# fyear   2017.00000    2023.0
# at     21795.13225  527854.0
# lt     11688.96900  325979.0
# teq    11260.59800  283379.0

# %% [markdown]
# negative equity

# %%
negative_teq_count = df[df['teq'] < 0].shape[0]
print(f"Number of rows with negative teq: {negative_teq_count}")

negative_teq_rows = df[df['teq'] < 0]
# negative_teq_rows
# Out:
# Number of rows with negative teq: 88

# %%
print(df.dtypes)
df
# Out:
# gvkey         int64
# datadate     object
# fyear         int64
# indfmt       object
# consol       object
# popsrc       object
# datafmt      object
# tic          object
# conm         object
# curcd        object
# at          float64
# lt          float64
# teq         float64
# costat       object
# dtype: object
# c:\Users\FBE RPG\anaconda3\lib\site-packages\IPython\core\formatters.py:344: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
#        gvkey    datadate  fyear indfmt consol popsrc datafmt   tic
# 0       1161  1990-12-31   1990   INDL      C      D     STD   AMD  \
# 1       1161  1991-12-31   1991   INDL      C      D     STD   AMD
# 2       1161  1992-12-31   1992   INDL      C      D     STD   AMD
# 3       1161  1993-12-31   1993   INDL      C      D     STD   AMD
# 4       1161  1994-12-31   1994   INDL      C      D     STD   AMD
# ...

# %% [markdown]
# normalization

# %%
df[['at_norm', 'lt_norm', 'teq_norm']] = df.groupby('tic')[['at', 'lt', 'teq']].transform(lambda x: (x - x.mean()) / x.std())

# %%
df_violin = df[['at_norm', 'lt_norm', 'teq_norm']].melt(var_name='variable', value_name='Normalized')
plt.figure(figsize=(12, 6))
ax = sns.violinplot(x='Column', y='Normalized', data=df_std)
_ = ax.set_xticklabels(df.keys(), rotation=90)
